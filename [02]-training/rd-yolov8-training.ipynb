# %%
print("Importing YAML file...")
run_name = 'ryu-test-1'
character = 'ryu'

yaml_path = '../input/' + run_name + "/" + run_name + "/" + character + "-data.yaml"
# !cp -r $yaml_path ./
########## Change name below manually
# !cp -r '../input/ryu-test-1/ryu-test-1/ryu-data.yaml' ./ # From '../input/' -> wokring directory because the input folder is read only
# %ls
# Out:
# Importing YAML file...
# input/  runs/  ryu-data.yaml  wandb/  yolov8s.pt
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)

# %%
    # # /kaggle/input/ryu-test-1/ryu-test-1/ryu-data.yaml
# # /kaggle/input/ryu-test-1/ryu-test-1/labels/val/SF3rdStrike-94933.txt
# # /kaggle/input/ryu-test-1/ryu-test-1/labels/val/SF3rdStrike-91174.txt
# # /kaggle/input/ryu-test-1/ryu-test-1/labels/val/SF3rdStrike-87882.txt

# %%
print("Installing wanb...")
# !pip install wandb --upgrade
import wandb
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("wanb-key")
# !wandb login $secret_value_0
# Out:
# Installing wanb...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 61.0 MB/s eta 0:00:00:00:010:01
# ...
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.17.0
#     Uninstalling wandb-0.17.0:
#       Successfully uninstalled wandb-0.17.0
# ...
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
print("Installing yolov8...")
# !pip install ultralytics
import torch
from IPython.display import Image, clear_output

clear_output()
# Out:
# Installing yolov8...
# ...

# %%
from ultralytics import YOLO
# model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8s.pt")  # load a pretrained model (recommended for training)

data_file = "/kaggle/working/" + character + "-data.yaml"

# Use the model
model.train(data = data_file, epochs=10, imgsz=640, name = run_name)  # train the model
metrics = model.val()  # evaluate model performance on the validation set
# Out:
# Ultralytics YOLOv8.2.30 🚀 Python-3.10.13 torch-2.1.2+cpu CPU (Intel Xeon 2.20GHz)
# ...

# %%
# %time
# !yolo detect train data="../input/ryu-test-1/ryu-test-1/ryu-data.yaml" model=yolov8s.pt epochs=13 imgsz=640

# # %cd ..
# # !zip -r /kaggle/working/WEIGHTS.zip ultralytics/runs/train/ryu-test-1/weights #If run fails, update this line to resultsN

# %%
# %cd working
# %ls
# Out:
# /kaggle/working
# runs/  yolov8s.pt

# %%
# %ls
# Out:
# runs/  yolov8s.pt
